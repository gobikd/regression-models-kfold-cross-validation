# %%
#import all libraries in sequence of use
import pandas as pd #same
from sklearn.model_selection import KFold, cross_val_score, cross_val_predict
from sklearn.ensemble import AdaBoostRegressor # ref: scikit-learn
import matplotlib.pyplot as plt
import numpy as np

# %%
dataset=pd.read_csv("../data/insurance_pre.csv")

# %%
dataset.columns
# Out:
# Index(['age', 'sex', 'bmi', 'children', 'smoker', 'charges'], dtype='object')

# %%
# dataset.replace({"male":1,"female":0, "yes":1,"no":0}, inplace=True)- Prevented in this instant
dataset=pd.get_dummies(dataset,drop_first=True,dtype=int)

# %%
dataset
dataset.head()
# Out:
#    age     bmi  children      charges  sex_male  smoker_yes
# 0   19  27.900         0  16884.92400         0           1
# 1   18  33.770         1   1725.55230         1           0
# 2   28  33.000         3   4449.46200         1           0
# 3   33  22.705         0  21984.47061         1           0
# 4   32  28.880         0   3866.85520         1           0

# %%
dataset.columns
# Out:
# Index(['age', 'bmi', 'children', 'charges', 'sex_male', 'smoker_yes'], dtype='object')

# %%
indep=dataset[['age', 'sex_male', 'bmi', 'children', 'smoker_yes']]

# %%
indep
# Out:
#       age  sex_male     bmi  children  smoker_yes
# 0      19         0  27.900         0           1
# 1      18         1  33.770         1           0
# 2      28         1  33.000         3           0
# 3      33         1  22.705         0           0
# 4      32         1  28.880         0           0
# ...   ...       ...     ...       ...         ...
# 1333   50         1  30.970         3           0
# 1334   18         0  31.920         0           0
# 1335   18         0  36.850         0           0
# 1336   21         0  25.800         0           0
# 1337   61         0  29.070         0           1
#
# [1338 rows x 5 columns]

# %%
dep=dataset[['charges']]

# %%
# Since K_Fold will do import train_test_split -disabled#
#from sklearn.model_selection import train_test_split 
#X_train,X_test,y_train,y_test=train_test_split(independent, dependent, test_size=0.30,random_state=0)
regressor=AdaBoostRegressor()
#-----------K-Fold--------------#
kfold = KFold(n_splits=10, shuffle=True, random_state=0)

scores = cross_val_score(
    estimator=regressor, #!! Regressor assigned
    X=indep, #!! Data X and Y assigned
    y=dep.values.ravel(),#                          
    cv=kfold, #<---------------from kfold=KFold          
    scoring="r2"
)
#-----------K-Fold--------------#
print("="*60)
print("R2 Score for each fold:", scores)
print("Mean R2:", scores.mean())
print("Standard Deviation:", scores.std())
print("="*60)
# Out:
# ...
# R2 Score for each fold: [0.90596965 0.77456198 0.84511763 0.83025908 0.76844024 0.74511875
#  0.82911236 0.80456771 0.82275324 0.78085844]
# Mean R2: 0.8106759067519095
# Standard Deviation: 0.04410056028511812
# ...

# %%
# Actual vs Predicted-A good model gives points close to the red diagonal
import matplotlib.pyplot as plt
prediction = cross_val_predict(regressor, indep, dep, cv=kfold)

plt.figure(figsize=(6,6))
plt.scatter(dep, prediction)
plt.plot(
    [dep.min(), dep.max()],
    [dep.min(), dep.max()],
    'r--')

plt.xlabel("Actual")
plt.ylabel("Predicted")
plt.title("AdaBoost Regression\nActual vs Predicted")

plt.show()
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# C:\ProgramData\Anaconda3\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# ...

# %%
# determine whether the model systematically overestimates or underestimates
residual = dep.values.ravel() - prediction
plt.figure(figsize=(6,4))
plt.scatter(prediction, residual)
plt.axhline(0, color='red')
plt.xlabel("Predicted")
plt.ylabel("Residual")
plt.title("Residual Plot")

plt.show()
